# %% [markdown]
# ## Kevin Santiago Benavides Rodriguez

# %% [markdown]
# Ingenieria Ambiental

# %% [markdown]
# La programación es una herramienta estratégica en la Ingeniería Ambiental que permite pasar del análisis manual a la gestión avanzada de ecosistemas y recursos

# %%
print("La programación es clave para monitorear la calidad del agua y prevenir la contaminación de ecosistemas.")
# Out:
# La programación es clave para monitorear la calidad del agua y prevenir la contaminación de ecosistemas.
