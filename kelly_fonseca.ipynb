# %% [markdown]
# ## Kelly Yajaira Fonseca Salguero

# %% [markdown]
# Ingeneria ambiental

# %% [markdown]
# La programacion permite a la ingeneria ambiental procesaar informacion de forma mas rapida y precisa.Con ella se pueden crear herramientas digitales para vigilar la contaminacion.

# %%
print("la calidad del agua se monitorea midiendo el pH, el oxigeno disuelto y la turbidez para asegurar la vida acuatica")
# Out:
# la calidad del agua se monitorea midiendo el pH, el oxigeno disuelto y la turbidez para asegurar la vida acuatica
